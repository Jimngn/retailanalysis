# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('retail_sales_dataset.csv', index_col = 'Transaction ID')
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
#                      Date Customer ID  Gender  Age Product Category  Quantity  \
# Transaction ID
# 1              2023-11-24     CUST001    Male   34           Beauty         3
# 2              2023-02-27     CUST002  Female   26         Clothing         2
# 3              2023-01-13     CUST003    Male   50      Electronics         1
# 4              2023-05-21     CUST004    Male   37         Clothing         1
# 5              2023-05-06     CUST005    Male   30           Beauty         2
# ...                   ...         ...     ...  ...              ...       ...
# 996            2023-05-16     CUST996    Male   62         Clothing         1
# 997            2023-11-17     CUST997    Male   52           Beauty         3
# 998            2023-10-29     CUST998  Female   23           Beauty         4
# 999            2023-12-05     CUST999  Female   36      Electronics         3
# 1000           2023-04-12    CUST1000    Male   47      Electronics         4
#
# ...

# %%
df.describe()
plt.figure(figsize=(14,6))
plt.title("Complete Data")
sns.lineplot(data = df, dashes = False)
# Out:
# <Axes: title={'center': 'Complete Data'}, xlabel='Transaction ID'>

# %%
plt.figure(figsize=(14,6))
plt.title("Complete Data")
sns.lineplot(data = df['Total Amount'], dashes = False)
# Out:
# <Axes: title={'center': 'Complete Data'}, xlabel='Transaction ID', ylabel='Total Amount'>

# %%
male = df.loc[df['Gender'] == 'Male'].count()

# %%
gender = df.loc[df['Gender'].count()

# %%
plt.figure(figsize = (10,6))
plt.title('Barchart girl vs boys')
sns.barplot(x = ('Male', 'Female'), y = (male, female))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/m8/6vszwx195fl9598f558j20ph0000gn/T/ipykernel_91606/171882648.py in ?()
#       1 plt.figure(figsize = (10,6))
#       2 plt.title('Barchart girl vs boys')
# ----> 3 sns.barplot(x = ('Male', 'Female'), y = (male, female))
#
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/seaborn/categorical.py in ?(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2337     # does not work in Series.agg (maybe a pandas bug?)
#    2338     if estimator is len:
#    2339         estimator = "size"
#    2340
# -> 2341     p = _CategoricalAggPlotter(
#    2342         data=data,
# ...

# %%
by_date = df.sort_values(['Date'], ascending = True)
total_sales_by_day = df.groupby('Date')['Total Amount'].sum()
total_sales_by_day
# Out:
# Date
# 2023-01-01    3600
# 2023-01-02    1765
# 2023-01-03     600
# 2023-01-04    1240
# 2023-01-05    1100
#               ...
# 2023-12-27     700
# 2023-12-28    2075
# 2023-12-29    3400
# 2023-12-31      50
# 2024-01-01    1530
# Name: Total Amount, Length: 345, dtype: int64

# %%
plt.figure(figsize=(16,6))
plt.title('Total sales day by day')
sns.lineplot(data=total_sales_by_day)
plt.ylim(0)
# Out:
# (0.0, 8876.5)

# %%
df.head(5)
# Out:
#                      Date Customer ID  Gender  Age Product Category  Quantity  \
# Transaction ID
# 1              2023-11-24     CUST001    Male   34           Beauty         3
# 2              2023-02-27     CUST002  Female   26         Clothing         2
# 3              2023-01-13     CUST003    Male   50      Electronics         1
# 4              2023-05-21     CUST004    Male   37         Clothing         1
# 5              2023-05-06     CUST005    Male   30           Beauty         2
#
#                 Price per Unit  Total Amount
# Transaction ID
# 1                           50           150
# 2                          500          1000
# 3                           30            30
# 4                          500           500
# 5                           50           100

# %%
df['Month'] = pd.to_datetime(df['Date']).dt.month
number_of_transaction_per_month = df.groupby('Month').count()
number_of_transaction_per_month
# Out:
#        Date  Customer ID  Gender  Age  Product Category  Quantity  \
# Month
# 1        78           78      78   78                78        78
# 2        85           85      85   85                85        85
# 3        73           73      73   73                73        73
# 4        86           86      86   86                86        86
# 5       105          105     105  105               105       105
# 6        77           77      77   77                77        77
# 7        72           72      72   72                72        72
# 8        94           94      94   94                94        94
# 9        65           65      65   65                65        65
# 10       96           96      96   96                96        96
# 11       78           78      78   78                78        78
# 12       91           91      91   91                91        91
#
#        Price per Unit  Total Amount
# Month
# 1                  78            78
# ...

# %%
df['Month'] = pd.to_datetime(df['Date']).dt.month
total_sales_by_month = df.groupby('Month')['Total Amount'].sum()
total_sales_by_month
# Out:
# Month
# 1     36980
# 2     44060
# 3     28990
# 4     33870
# 5     53150
# 6     36715
# 7     35465
# 8     36960
# 9     23620
# 10    46580
# 11    34920
# 12    44690
# Name: Total Amount, dtype: int64

# %%
plt.figure(figsize=(16,6))
plt.title("Total sales by month")
sns.lineplot(data=total_sales_by_month)
# Out:
# <Axes: title={'center': 'Total sales by month'}, xlabel='Month', ylabel='Total Amount'>

# %%
df
# Out:
#                      Date Customer ID  Gender  Age Product Category  Quantity  \
# Transaction ID
# 1              2023-11-24     CUST001    Male   34           Beauty         3
# 2              2023-02-27     CUST002  Female   26         Clothing         2
# 3              2023-01-13     CUST003    Male   50      Electronics         1
# 4              2023-05-21     CUST004    Male   37         Clothing         1
# 5              2023-05-06     CUST005    Male   30           Beauty         2
# ...                   ...         ...     ...  ...              ...       ...
# 996            2023-05-16     CUST996    Male   62         Clothing         1
# 997            2023-11-17     CUST997    Male   52           Beauty         3
# 998            2023-10-29     CUST998  Female   23           Beauty         4
# 999            2023-12-05     CUST999  Female   36      Electronics         3
# 1000           2023-04-12    CUST1000    Male   47      Electronics         4
#
# ...
