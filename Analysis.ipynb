# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('retail_sales_dataset.csv', index_col = 'Transaction ID')
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
#                      Date Customer ID  Gender  Age Product Category  Quantity  \
# Transaction ID
# 1              2023-11-24     CUST001    Male   34           Beauty         3
# 2              2023-02-27     CUST002  Female   26         Clothing         2
# 3              2023-01-13     CUST003    Male   50      Electronics         1
# 4              2023-05-21     CUST004    Male   37         Clothing         1
# 5              2023-05-06     CUST005    Male   30           Beauty         2
# ...                   ...         ...     ...  ...              ...       ...
# 996            2023-05-16     CUST996    Male   62         Clothing         1
# 997            2023-11-17     CUST997    Male   52           Beauty         3
# 998            2023-10-29     CUST998  Female   23           Beauty         4
# 999            2023-12-05     CUST999  Female   36      Electronics         3
# 1000           2023-04-12    CUST1000    Male   47      Electronics         4
#
# ...

# %%
df.describe()
sns.lineplot(data = df, size = [10])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[83], line 2
#       1 df.describe()
# ----> 2 sns.lineplot(data = df, size = 10)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/seaborn/relational.py:485, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     471 def lineplot(
#     472     data=None, *,
#     473     x=None, y=None, hue=None, size=None, style=None, units=None, weights=None,
#    (...)
#     481
#     482     # Handle deprecation of ci parameter
#     483     errorbar = _deprecate_ci(errorbar, ci)
# --> 485     p = _LinePlotter(
#     486         data=data,
#     487         variables=dict(
# ...

# %%
df.loc[df['Gender'] == 'Male'].count()
# Out:
# Date                490
# Customer ID         490
# Gender              490
# Age                 490
# Product Category    490
# Quantity            490
# Price per Unit      490
# Total Amount        490
# dtype: int64

# %%
data.loc[data['Gender'] == 'Female'].count()
# Out:
# Transaction ID      510
# Date                510
# Customer ID         510
# Gender              510
# Age                 510
# Product Category    510
# Quantity            510
# Price per Unit      510
# Total Amount        510
# dtype: int64

# %%
by_date = df.sort_values(['Date'], ascending = True)
by_date = df.drop(['Customer ID'], axis = 'columns')
total_sales_by_day = df.groupby('Date')['Total Amount'].sum()
total_sales_by_day
# Out:
# Date
# 2023-01-01    3600
# 2023-01-02    1765
# 2023-01-03     600
# 2023-01-04    1240
# 2023-01-05    1100
#               ...
# 2023-12-27     700
# 2023-12-28    2075
# 2023-12-29    3400
# 2023-12-31      50
# 2024-01-01    1530
# Name: Total Amount, Length: 345, dtype: int64

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=total_sales_by_day)
# Out:
# <Axes: xlabel='Date', ylabel='Total Amount'>

# %%
df['Month'] = pd.to_datetime(df['Date']).dt.month
total_sales_by_month = df.groupby('Month')['Total Amount'].sum()
total_sales_by_month
# Out:
# Month
# 1     36980
# 2     44060
# 3     28990
# 4     33870
# 5     53150
# 6     36715
# 7     35465
# 8     36960
# 9     23620
# 10    46580
# 11    34920
# 12    44690
# Name: Total Amount, dtype: int64

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=total_sales_by_month)
# Out:
# <Axes: xlabel='Month', ylabel='Total Amount'>
